# %% [markdown]
# <a href="https://colab.research.google.com/github/luigi-valori/YOLOv8-Streetlamp-Tracking/blob/main/Yolov8_Streetlamp_Tracking.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ##Preparazione ambiente

# %% [markdown]
# ####Verifica GPU

# %%
# !nvidia-smi

# %% [markdown]
# ####Collegamento Drive

# %%
from google.colab import drive

drive.mount('/content/drive')

# %% [markdown]
# ####Gestione directory

# %%
import os

BASE_PATH = '/content/drive/MyDrive/Progetto_Tesi_IA'
DATASET_PATH = os.path.join(BASE_PATH, 'dataset')
WEIGHTS_PATH = os.path.join(BASE_PATH, 'pesi_modelli')
PSEUDO_PATH = os.path.join(BASE_PATH, 'pseudo_labels')
VIDEO_PATH = os.path.join(BASE_PATH, 'video_test')

yaml_file = os.path.join(DATASET_PATH, 'data.yaml')
print(f"{yaml_file}")

# %% [markdown]
# ##Installazione librerie

# %% [markdown]
# ####Ultralitics

# %%
# !pip install ultralytics==8.3.19

from IPython.display import clear_output
clear_output()

# !yolo settings sync=False

import ultralytics
ultralytics.checks()

# %% [markdown]
# ####Supervision

# %%
# !pip install supervision[assets]==0.24.0

clear_output()

import supervision as sv
print("Installed supervision:", sv.__version__)

# %% [markdown]
# ####Motmetrics

# %%
# !pip install motmetrics

import motmetrics as mm
print("Installed supervision:", mm.__version__)
